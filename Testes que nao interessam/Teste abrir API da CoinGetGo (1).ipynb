# %%
import pandas as pd
import numpy
import matplotlib.pyplot as plt
import requests

# %%
#list of cryptocurrency pairs

url = 'https://api.coingecko.com/api/v3/global'
data = requests.get(url).json()
df = pd.DataFrame.from_dict(data)
df
# Out:
#                                                                                    data
# active_cryptocurrencies                                                            7208
# ended_icos                                                                         3375
# market_cap_change_percentage_24h_usd                                           -1.66111
# market_cap_percentage                 {'btc': 41.56630782126563, 'eth': 19.232847907...
# markets                                                                             612
# ongoing_icos                                                                         50
# total_market_cap                      {'btc': 45008115.90109223, 'eth': 602604285.38...
# total_volume                          {'btc': 5695992.72063542, 'eth': 76262459.6536...
# upcoming_icos                                                                         0
# updated_at                                                                   1620844640

# %%
#list of cryptocurrency pairs

url = 'https://api.coingecko.com/api/v3/coins/markets?vs_currency=usd&order=market_cap_desc&per_page=6938&page=1&sparkline=false'
data = requests.get(url).json()
df = pd.DataFrame.from_dict(data)
df.set_index ("market_cap_rank")
# Out:
#                           id symbol          name  \
# market_cap_rank
# 1                    bitcoin    btc       Bitcoin
# 2                   ethereum    eth      Ethereum
# 3                binancecoin    bnb  Binance Coin
# 4                     ripple    xrp           XRP
# 5                   dogecoin   doge      Dogecoin
# ...                      ...    ...           ...
# 247                    metal    mtl         Metal
# 253              compound-0x   czrx           c0x
# 246                   insure   sure   inSure DeFi
# 248                  safepal    sfp       SafePal
# 249                 ellipsis    eps      Ellipsis
#
#                                                              image  \
# market_cap_rank
# 1                https://assets.coingecko.com/coins/images/1/la...
# 2                https://assets.coingecko.com/coins/images/279/...
# 3                https://assets.coingecko.com/coins/images/825/...
# ...

# %%
url = 'https://api.coingecko.com/api/v3/coins/dogecoin/market_chart?vs_currency=usd&days=365'
data = requests.get(url).json()
df = pd.DataFrame.from_dict(data)
df
# Out:
#                                      prices  \
# 0      [1589328000000, 0.00246437921702702]
# 1     [1589414400000, 0.002552333081264038]
# 2    [1589500800000, 0.0026081946608221976]
# 3    [1589587200000, 0.0024727558171709174]
# 4     [1589673600000, 0.002515121829380273]
# ..                                      ...
# 361      [1620518400000, 0.633615145089309]
# 362     [1620604800000, 0.5731359699349188]
# 363     [1620691200000, 0.4511289031456602]
# 364     [1620777600000, 0.4967308443014721]
# 365      [1620834977000, 0.473489997564172]
#
#                              market_caps                        total_volumes
# 0    [1589328000000, 306504298.82334745]  [1589328000000, 203607474.54131982]
# 1     [1589414400000, 317877729.3660128]  [1589414400000, 211321832.63797155]
# 2    [1589500800000, 325137727.16545933]  [1589500800000, 230680148.75764883]
# 3     [1589587200000, 308034839.7949836]  [1589587200000, 198862295.41764167]
# ...

# %%
url = 'https://api.coingecko.com/api/v3/coins/bitcoin/market_chart?vs_currency=usd&days=365'
data = requests.get(url).json()
df = pd.DataFrame.from_dict(data)
df
# Out:
#                                   prices                          market_caps  \
# 0     [1589328000000, 8788.466749414652]    [1589328000000, 161474125336.405]
# 1      [1589414400000, 9283.08601265873]  [1589414400000, 170593350055.82486]
# 2     [1589500800000, 9796.494527024528]   [1589500800000, 179398095871.3398]
# 3      [1589587200000, 9309.29535940684]  [1589587200000, 170983863891.47488]
# 4      [1589673600000, 9375.29710843331]  [1589673600000, 172309401206.74423]
# ..                                   ...                                  ...
# 361  [1620518400000, 58771.881689509355]  [1620518400000, 1099271802311.4957]
# 362  [1620604800000, 58213.926293744385]  [1620604800000, 1088903483393.3053]
# 363   [1620691200000, 55901.66759456145]  [1620691200000, 1045714370754.1615]
# 364   [1620777600000, 56928.97235660158]  [1620777600000, 1064993057463.8884]
# 365   [1620804575000, 57194.29167091639]  [1620804575000, 1068932052948.8788]
#
# ...

# %%
prices = df["prices"]
market_caps = df["market_caps"]
total_volumes = df["total_volumes"]

btcusdprices = []
btcusdmarketcap = []
btcusdvolume = []
btcusdtime = []
day = 1

for i in range(len(prices)):
    price = prices[i]
    marketcap = market_caps[i]
    volume = total_volumes[i]
    btcusdtime.append(day)
    day += 1
    btcusdmarketcap.append(marketcap[1])
    btcusdvolume.append(volume[1])
    btcusdprices.append(price[1])
    
btcusd = {"BTCUSD":btcusdprices, "MarketCap":btcusdmarketcap, "Volume":btcusdvolume}
    
df_btc_prices = pd.DataFrame(data=btcusd, index=btcusdtime)
df_btc_prices
# Out:
#            BTCUSD     MarketCap        Volume
# 1     8788.466749  1.614741e+11  3.951546e+10
# 2     9283.086013  1.705934e+11  4.423995e+10
# 3     9796.494527  1.793981e+11  5.207659e+10
# 4     9309.295359  1.709839e+11  4.486685e+10
# 5     9375.297108  1.723094e+11  3.414649e+10
# ..            ...           ...           ...
# 362  58771.881690  1.099272e+12  6.681217e+10
# 363  58213.926294  1.088903e+12  6.790628e+10
# 364  55901.667595  1.045714e+12  7.667298e+10
# 365  56928.972357  1.064993e+12  6.772671e+10
# 366  57194.291671  1.068932e+12  6.239783e+10
#
# [366 rows x 3 columns]

# %%
url = 'https://api.coingecko.com/api/v3/coins/ethereum/market_chart?vs_currency=usd&days=365'
data = requests.get(url).json()
df = pd.DataFrame.from_dict(data)

df
# Out:
#                                   prices                          market_caps  \
# 0    [1589328000000, 189.30578181851274]  [1589328000000, 20993946147.950317]
# 1    [1589414400000, 199.36937254304945]    [1589414400000, 22169692740.7452]
# 2    [1589500800000, 203.21124699378416]   [1589500800000, 22562017222.46954]
# 3    [1589587200000, 194.27309778153102]   [1589587200000, 21656663418.09443]
# 4    [1589673600000, 200.58339090310048]  [1589673600000, 22256509489.004852]
# ..                                   ...                                  ...
# 361  [1620518400000, 3912.7429165968124]  [1620518400000, 450716254202.56744]
# 362   [1620604800000, 3932.754068170969]   [1620604800000, 455448294000.9345]
# 363  [1620691200000, 3979.6086519212827]  [1620691200000, 461040789541.05756]
# 364   [1620777600000, 4182.790285752286]  [1620777600000, 481380994613.09344]
# 365   [1620804585000, 4311.093863076467]   [1620804585000, 499398440372.4899]
#
# ...

# %%
prices = df["prices"]
market_caps = df["market_caps"]
total_volumes = df["total_volumes"]

ethusdprices = []
ethusdmarketcap = []
ethusdvolume = []
ethusdtime = []
day = 1

for i in range(len(prices)):
    price = prices[i]
    marketcap = market_caps[i]
    volume = total_volumes[i]
    ethusdtime.append(day)
    day += 1
    ethusdmarketcap.append(marketcap[1])
    ethusdvolume.append(volume[1])
    ethusdprices.append(price[1])
    
ethusd = {"ETHUSD":ethusdprices, "MarketCap":ethusdmarketcap, "Volume":ethusdvolume}
    
dfprices = pd.DataFrame(data=ethusd, index=ethusdtime)
dfprices
# Out:
#           ETHUSD     MarketCap        Volume
# 1     189.305782  2.099395e+10  1.370675e+10
# 2     199.369373  2.216969e+10  1.340359e+10
# 3     203.211247  2.256202e+10  1.815330e+10
# 4     194.273098  2.165666e+10  1.313082e+10
# 5     200.583391  2.225651e+10  1.167676e+10
# ..           ...           ...           ...
# 362  3912.742917  4.507163e+11  6.017492e+10
# 363  3932.754068  4.554483e+11  6.162566e+10
# 364  3979.608652  4.610408e+11  8.082722e+10
# 365  4182.790286  4.813810e+11  6.786920e+10
# 366  4311.093863  4.993984e+11  6.394170e+10
#
# [366 rows x 3 columns]

# %%
url = 'https://api.coingecko.com/api/v3/global'
data = requests.get(url).json()
df = pd.DataFrame.from_dict(data)
df
# Out:
#                                                                                    data
# active_cryptocurrencies                                                            7208
# ended_icos                                                                         3375
# market_cap_change_percentage_24h_usd                                           -1.66111
# market_cap_percentage                 {'btc': 41.56630782126563, 'eth': 19.232847907...
# markets                                                                             612
# ongoing_icos                                                                         50
# total_market_cap                      {'btc': 45008115.90109223, 'eth': 602604285.38...
# total_volume                          {'btc': 5695992.72063542, 'eth': 76262459.6536...
# upcoming_icos                                                                         0
# updated_at                                                                   1620844640
