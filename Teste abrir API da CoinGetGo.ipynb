# %%
import pandas as pd
import numpy
import matplotlib.pyplot as plt
import requests

# %%
#list of cryptocurrency pairs

url = 'https://api.coingecko.com/api/v3/global'
data = requests.get(url).json()
df = pd.DataFrame.from_dict(data)
df
# Out:
#                                                                                    data
# active_cryptocurrencies                                                            7048
# ended_icos                                                                         3375
# market_cap_change_percentage_24h_usd                                            1.00754
# market_cap_percentage                 {'btc': 43.45612157861751, 'eth': 16.450455019...
# markets                                                                             605
# ongoing_icos                                                                         50
# total_market_cap                      {'btc': 43032629.97405053, 'eth': 703464510.52...
# total_volume                          {'btc': 6692182.983263225, 'eth': 109398687.21...
# upcoming_icos                                                                         0
# updated_at                                                                   1620212795

# %%
#list of cryptocurrency pairs

url = 'https://api.coingecko.com/api/v3/coins/markets?vs_currency=usd&order=market_cap_desc&per_page=6938&page=1&sparkline=false'
data = requests.get(url).json()
df = pd.DataFrame.from_dict(data)
df
# Out:
#                 id symbol           name  \
# 0          bitcoin    btc        Bitcoin
# 1         ethereum    eth       Ethereum
# 2      binancecoin    bnb   Binance Coin
# 3         dogecoin   doge       Dogecoin
# 4           ripple    xrp            XRP
# ..             ...    ...            ...
# 245  oasis-network   rose  Oasis Network
# 246    kardiachain    kai    KardiaChain
# 247           coti   coti           COTI
# 248       verasity    vra       Verasity
# 249      tomochain   tomo      TomoChain
#
#                                                  image  current_price  \
# 0    https://assets.coingecko.com/coins/images/1/la...   55427.000000
# 1    https://assets.coingecko.com/coins/images/279/...    3376.720000
# 2    https://assets.coingecko.com/coins/images/825/...     651.020000
# 3    https://assets.coingecko.com/coins/images/5/la...       0.677756
# 4    https://assets.coingecko.com/coins/images/44/l...       1.470000
# ..                                                 ...            ...
# 245  https://assets.coingecko.com/coins/images/1316...       0.164857
# 246  https://assets.coingecko.com/coins/images/7942...       0.115299
# 247  https://assets.coingecko.com/coins/images/2962...       0.360620
# 248  https://assets.coingecko.com/coins/images/1402...       0.035920
# 249  https://assets.coingecko.com/coins/images/3416...       2.870000
#
#         market_cap  market_cap_rank  fully_diluted_valuation  total_volume  \
# 0    1038882374939                1             1.166640e+12  7.309530e+10
# 1     390998551901                2                      NaN  7.483319e+10
# 2     100715473243                3             1.111433e+11  6.509308e+09
# 3      88002883865                4                      NaN  5.147993e+10
# 4      67847288886                5                      NaN  1.176087e+10
# ..             ...              ...                      ...           ...
# 245      247291383              246             1.648609e+09  2.269289e+07
# 246      246166745              247                      NaN  4.352850e+06
# 247      241913672              248             7.224104e+08  7.948479e+07
# 248      236719171              249                      NaN  2.994442e+07
# 249      233436663              250                      NaN  4.188807e+07
#
#          high_24h  ...  total_supply    max_supply           ath  \
# 0    56366.000000  ...  2.100000e+07  2.100000e+07  64805.000000
# 1     3519.550000  ...           NaN           NaN   3519.550000
# 2      655.520000  ...  1.705337e+08  1.705337e+08    677.470000
# 3        0.686020  ...           NaN           NaN      0.686020
# 4        1.480000  ...  1.000000e+11           NaN      3.400000
# ..            ...  ...           ...           ...           ...
# 245      0.167975  ...  1.000000e+10  1.000000e+10      0.245930
# 246      0.126900  ...  5.000000e+09           NaN      0.160205
# 247      0.372283  ...  2.000000e+09  2.000000e+09      0.572352
# 248      0.038407  ...  1.035653e+10           NaN      0.055664
# 249      2.920000  ...  1.000000e+08           NaN      3.610000
#
#      ath_change_percentage                  ath_date        atl  \
# 0                -14.35041  2021-04-14T11:54:46.763Z  67.810000
# 1                 -3.82237  2021-05-04T13:34:43.987Z   0.432979
# 2                 -4.30317  2021-05-03T17:44:19.191Z   0.039818
# 3                 -0.95242  2021-05-05T06:30:31.582Z   0.000087
# 4                -56.59554  2018-01-07T00:00:00.000Z   0.002686
# ..                     ...                       ...        ...
# 245              -32.84373  2021-03-15T01:49:46.536Z   0.032006
# 246              -27.89232  2021-04-14T10:19:05.859Z   0.000403
# 247              -36.80612  2021-03-23T13:29:18.497Z   0.005563
# 248              -34.99015  2021-04-17T04:48:57.942Z   0.001995
# 249              -20.68644  2021-04-10T15:39:45.110Z   0.139955
#
#      atl_change_percentage                  atl_date  \
# 0             8.175489e+04  2013-07-06T00:00:00.000Z
# 1             7.816994e+05  2015-10-20T00:00:00.000Z
# 2             1.628112e+06  2017-10-19T00:00:00.000Z
# 3             7.817837e+05  2015-05-06T00:00:00.000Z
# 4             5.481308e+04  2014-05-22T00:00:00.000Z
# ..                     ...                       ...
# 245           4.160246e+02  2020-11-26T17:09:12.182Z
# 246           2.856886e+04  2020-05-11T10:12:22.721Z
# 247           6.401241e+03  2019-11-07T10:29:26.372Z
# 248           1.713803e+03  2021-02-23T11:58:52.567Z
# 249           1.947401e+03  2020-03-13T02:24:15.954Z
#
#                                                    roi  \
# 0                                                 None
# 1    {'times': 80.56857332782276, 'currency': 'btc'...
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 245                                               None
# 246                                               None
# 247  {'times': 4.548000625093, 'currency': 'usd', '...
# 248                                               None
# 249  {'times': 10.469900044116144, 'currency': 'usd...
#
#                  last_updated
# 0    2021-05-05T11:15:23.964Z
# 1    2021-05-05T11:15:20.386Z
# 2    2021-05-05T11:13:21.712Z
# 3    2021-05-05T11:10:47.571Z
# 4    2021-05-05T11:15:33.134Z
# ..                        ...
# 245  2021-05-05T11:14:07.082Z
# 246  2021-05-05T11:13:33.154Z
# 247  2021-05-05T11:10:56.507Z
# 248  2021-05-05T11:12:59.957Z
# 249  2021-05-05T11:11:35.170Z
#
# [250 rows x 26 columns]

# %%
url = 'https://api.coingecko.com/api/v3/coins/dogecoin/market_chart?vs_currency=usd&days=365'
data = requests.get(url).json()
df = pd.DataFrame.from_dict(data)
df
# Out:
#                                      prices  \
# 0     [1588723200000, 0.002492679926068163]
# 1     [1588809600000, 0.002515865355671929]
# 2    [1588896000000, 0.0026795755607618133]
# 3     [1588982400000, 0.002610648868243647]
# 4     [1589068800000, 0.002580034050146067]
# ..                                      ...
# 361     [1619913600000, 0.3934034093428363]
# 362     [1620000000000, 0.3786878456706408]
# 363     [1620086400000, 0.4414119504765905]
# 364     [1620172800000, 0.5439150763274362]
# 365      [1620199876000, 0.680764796515795]
#
#                              market_caps                        total_volumes
# 0     [1588723200000, 310190099.1707827]  [1588723200000, 191425230.39362994]
# 1    [1588809600000, 313109921.02338296]  [1588809600000, 194670688.82242593]
# 2    [1588896000000, 333521246.82060003]   [1588896000000, 231863021.6014279]
# 3     [1588982400000, 325727926.6156065]   [1588982400000, 233587352.8328149]
# 4     [1589068800000, 321346729.6707498]  [1589068800000, 232331569.78586742]
# ..                                   ...                                  ...
# 361   [1619913600000, 50748955079.41196]  [1619913600000, 11619063047.262308]
# 362   [1620000000000, 49014916719.25478]   [1620000000000, 9009865374.508814]
# 363  [1620086400000, 57139646560.002594]   [1620086400000, 11357873988.20906]
# 364   [1620172800000, 71252122861.90167]   [1620172800000, 39500407577.68589]
# 365   [1620199876000, 88071438964.98184]    [1620199876000, 54460492375.5417]
#
# [366 rows x 3 columns]

# %%
url = 'https://api.coingecko.com/api/v3/coins/bitcoin/market_chart?vs_currency=usd&days=365'
data = requests.get(url).json()
df = pd.DataFrame.from_dict(data)
df
# Out:
#                                  prices                          market_caps  \
# 0    [1588723200000, 9003.240557621584]  [1588723200000, 165335617639.04947]
# 1     [1588809600000, 9144.68703972007]   [1588809600000, 167950864937.1468]
# 2    [1588896000000, 9959.166416261767]  [1588896000000, 182927847431.44946]
# 3     [1588982400000, 9821.81131529702]   [1588982400000, 180421762956.3486]
# 4    [1589068800000, 9566.777187205966]  [1589068800000, 175752574354.63544]
# ..                                  ...                                  ...
# 361  [1619913600000, 57812.96915967891]  [1619913600000, 1080897634123.2937]
# 362  [1620000000000, 56600.74528738432]  [1620000000000, 1057850321948.5465]
# 363  [1620086400000, 57200.30029871162]  [1620086400000, 1069571255195.5189]
# 364  [1620172800000, 53464.37021950372]   [1620172800000, 999775008412.3738]
# 365  [1620199720000, 54570.92502802651]  [1620199720000, 1022663752674.4353]
#
#                            total_volumes
# 0     [1588723200000, 43436234291.97107]
# 1    [1588809600000, 48538811466.802704]
# 2     [1588896000000, 61712313964.69186]
# 3     [1588982400000, 50955646313.40579]
# 4     [1589068800000, 46706541180.09866]
# ..                                   ...
# 361   [1619913600000, 43967070045.82312]
# 362  [1620000000000, 39072664393.929405]
# 363   [1620086400000, 54132470274.07509]
# 364   [1620172800000, 71296763919.13268]
# 365   [1620199720000, 71808422078.71939]
#
# [366 rows x 3 columns]

# %%
prices = df["prices"]
market_caps = df["market_caps"]
total_volumes = df["total_volumes"]

btcusdprices = []
btcusdmarketcap = []
btcusdvolume = []
btcusdtime = []
day = 1

for i in range(len(prices)):
    price = prices[i]
    marketcap = market_caps[i]
    volume = total_volumes[i]
    btcusdtime.append(day)
    day += 1
    btcusdmarketcap.append(marketcap[1])
    btcusdvolume.append(volume[1])
    btcusdprices.append(price[1])
    
btcusd = {"ETHUSD":btcusdprices, "MarketCap":btcusdmarketcap, "Volume":btcusdvolume}
    
df_btc_prices = pd.DataFrame(data=btcusd, index=btcusdtime)
df_btc_prices
# Out:
#            ETHUSD     MarketCap        Volume
# 1     9003.240558  1.653356e+11  4.343623e+10
# 2     9144.687040  1.679509e+11  4.853881e+10
# 3     9959.166416  1.829278e+11  6.171231e+10
# 4     9821.811315  1.804218e+11  5.095565e+10
# 5     9566.777187  1.757526e+11  4.670654e+10
# ..            ...           ...           ...
# 362  57812.969160  1.080898e+12  4.396707e+10
# 363  56600.745287  1.057850e+12  3.907266e+10
# 364  57200.300299  1.069571e+12  5.413247e+10
# 365  53464.370220  9.997750e+11  7.129676e+10
# 366  54570.925028  1.022664e+12  7.180842e+10
#
# [366 rows x 3 columns]

# %%
url = 'https://api.coingecko.com/api/v3/coins/ethereum/market_chart?vs_currency=usd&days=365'
data = requests.get(url).json()
df = pd.DataFrame.from_dict(data)

df
# Out:
#                                   prices                          market_caps  \
# 0    [1588723200000, 205.22517973985205]  [1588723200000, 22740460359.466698]
# 1    [1588809600000, 200.25479450009442]  [1588809600000, 22529347281.111214]
# 2    [1588896000000, 212.29247620086525]  [1588896000000, 23678773321.927563]
# 3    [1588982400000, 211.68904835113835]   [1588982400000, 23476076684.66088]
# 4     [1589068800000, 210.4318181376063]  [1589068800000, 23328821609.133904]
# ..                                   ...                                  ...
# 361  [1619913600000, 2944.9169473185057]  [1619913600000, 340730211563.77893]
# 362  [1620000000000, 2953.2973480804735]  [1620000000000, 341953594507.36664]
# 363  [1620086400000, 3439.8550695192603]    [1620086400000, 398258027094.341]
# 364   [1620172800000, 3245.663148933579]    [1620172800000, 380565712269.779]
# 365  [1620199678000, 3292.2278569064133]   [1620199678000, 380283240513.2039]
#
#                            total_volumes
# 0    [1588723200000, 14345915703.711891]
# 1     [1588809600000, 18128961143.16994]
# 2    [1588896000000, 15142506242.294548]
# 3     [1588982400000, 18337241719.88773]
# 4    [1589068800000, 15514402336.324596]
# ..                                   ...
# 361   [1619913600000, 36721647718.00421]
# 362   [1620000000000, 35727432415.51426]
# 363   [1620086400000, 64192650586.42862]
# 364   [1620172800000, 78437235045.70189]
# 365   [1620199678000, 73976672223.21132]
#
# [366 rows x 3 columns]

# %%
prices = df["prices"]
market_caps = df["market_caps"]
total_volumes = df["total_volumes"]

ethusdprices = []
ethusdmarketcap = []
ethusdvolume = []
ethusdtime = []
day = 1

for i in range(len(prices)):
    price = prices[i]
    marketcap = market_caps[i]
    volume = total_volumes[i]
    ethusdtime.append(day)
    day += 1
    ethusdmarketcap.append(marketcap[1])
    ethusdvolume.append(volume[1])
    ethusdprices.append(price[1])
    
ethusd = {"ETHUSD":ethusdprices, "MarketCap":ethusdmarketcap, "Volume":ethusdvolume}
    
dfprices = pd.DataFrame(data=ethusd, index=ethusdtime)
dfprices
# Out:
#           ETHUSD     MarketCap        Volume
# 1     205.225180  2.274046e+10  1.434592e+10
# 2     200.254795  2.252935e+10  1.812896e+10
# 3     212.292476  2.367877e+10  1.514251e+10
# 4     211.689048  2.347608e+10  1.833724e+10
# 5     210.431818  2.332882e+10  1.551440e+10
# ..           ...           ...           ...
# 362  2944.916947  3.407302e+11  3.672165e+10
# 363  2953.297348  3.419536e+11  3.572743e+10
# 364  3439.855070  3.982580e+11  6.419265e+10
# 365  3245.663149  3.805657e+11  7.843724e+10
# 366  3292.227857  3.802832e+11  7.397667e+10
#
# [366 rows x 3 columns]

# %%
url = 'https://api.coingecko.com/api/v3/global'
data = requests.get(url).json()
df = pd.DataFrame.from_dict(data)
df
# Out:
#                                                                                    data
# active_cryptocurrencies                                                            7049
# ended_icos                                                                         3375
# market_cap_change_percentage_24h_usd                                           0.984542
# market_cap_percentage                 {'btc': 43.45048464933869, 'eth': 16.292331639...
# markets                                                                             606
# ongoing_icos                                                                         50
# total_market_cap                      {'btc': 43038429.03230912, 'eth': 711062497.72...
# total_volume                          {'btc': 6572347.180409839, 'eth': 108585506.18...
# upcoming_icos                                                                         0
# updated_at                                                                   1620221810
